# %% [markdown]
# # mtcnn人脸检测

# %%
from src import detect_faces, show_bboxes
from PIL import Image

img = Image.open('images/liu.jpg')
bounding_boxes, landmarks = detect_faces(img)
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# D:\Desktop\mtcnn-pytorch-master\src\first_stage.py:32: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(torch.FloatTensor(_preprocess(img)), volatile=True)
# D:\Desktop\mtcnn-pytorch-master\src\get_nets.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# D:\Desktop\mtcnn-pytorch-master\src\detector.py:79: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# D:\Desktop\mtcnn-pytorch-master\src\get_nets.py:115: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# D:\Desktop\mtcnn-pytorch-master\src\detector.py:100: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# D:\Desktop\mtcnn-pytorch-master\src\get_nets.py:168: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# <PIL.Image.Image image mode=RGB size=620x867 at 0x1484F6C0488>

# %% [markdown]
# # 裁剪

# %%
img_crop=img.crop(bounding_boxes[0][:4])
np.shape(img_crop)
img_crop
# Out:
# <PIL.Image.Image image mode=RGB size=192x269 at 0x1484F6E3248>

# %% [markdown]
# # 缩放

# %%
img_resize=img_crop.resize((112,96),Image.ANTIALIAS)
img_resize
# Out:
# <PIL.Image.Image image mode=RGB size=112x96 at 0x1484F6E3948>

# %% [markdown]
# # 对齐
